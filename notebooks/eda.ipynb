# %%
import sys 

sys.path.append('../')

# %%
from data.dataloaders import PH2Dataset, DRIVEDataset

ph2_data = PH2Dataset(train=True, transform=None)

# %%
from helpers.statistics import describe_basic, describe_sizes, describe_structure

# Quick dataset description
describe_basic(ph2_data)
# Out:
# Total samples: 200
# Images: 200
# Masks: 200

# %%
describe_sizes(ph2_data)
# Out:
# Image sizes:
#   Height: 553-577 (mean: 575)
#   Width:  761-769 (mean: 766)
#
# Mask sizes:
#   Height: 553-577 (mean: 575)
#   Width:  761-769 (mean: 766)
#
# Unique image sizes: 24

# %%
describe_structure(ph2_data)
# Out:
# Image: BmpImageFile, shape: (572, 765, 3), dtype: uint8
#   Value range: [0, 255]
#
# Mask: BmpImageFile, shape: (572, 765), dtype: bool
#   Value range: [False, True]
#   Unique values: [False  True]

# %%
drivedataset = DRIVEDataset()

describe_structure(drivedataset)
# Out:
# Image: TiffImageFile, shape: (584, 565, 3), dtype: uint8
#   Value range: [0, 255]
#
# Mask: GifImageFile, shape: (584, 565), dtype: uint8
#   Value range: [0, 255]
#   Unique values: [  0 255]

# %%
describe_basic(drivedataset)
# Out:
# Total samples: 20
# Images: 20
# Masks: 20

# %%
describe_sizes(drivedataset)
# Out:
# Image sizes:
#   Height: 584-584 (mean: 584)
#   Width:  565-565 (mean: 565)
#
# Mask sizes:
#   Height: 584-584 (mean: 584)
#   Width:  565-565 (mean: 565)
#
# Unique image sizes: 1
#   (np.int64(584), np.int64(565)): 20 images
